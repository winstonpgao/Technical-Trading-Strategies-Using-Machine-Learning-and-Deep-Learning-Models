# %%
# import requests
# r = requests.get('https://finnhub.io/api/v1/news-sentiment?symbol=AAPL&token=c0tpqan48v6qoe9bm5o0')
# print(r.json())

# %%
import requests
import pandas as pd

# %%
r = requests.get('https://finnhub.io/api/v1/company-news?symbol=AAPL&from=2010-01-01&to=2020-05-01&token=c0tpqan48v6qoe9bm5o0')
news_df = pd.DataFrame(r.json())
news_df.shape
# Out:
# (500, 9)

# %%
from datetime import datetime
test = datetime.fromtimestamp(news_df.loc[1,'datetime']).strftime('%Y-%m-%d %H:%M:%S')
test
# Out:
# '2020-05-02 10:00:00'

# %%
for i in range(0, len(news_df)): 
    news_df["datetime"][i]=datetime.fromtimestamp(news_df["datetime"][i]).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# C:\Users\LEON\anaconda3\envs\monenv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\LEON\anaconda3\envs\monenv\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
news_df
# Out:
#          category             datetime  \
# 0         company  2020-05-02 10:00:00
# 1         company  2020-05-02 10:00:00
# 2         company  2020-05-02 10:00:00
# 3         company  2020-05-02 10:00:00
# 4         company  2020-05-02 10:00:00
# 5         company  2020-05-02 10:00:00
# 6         company  2020-05-02 10:00:00
# 7         company  2020-05-02 10:00:00
# 8         company  2020-05-02 10:00:00
# 9         company  2020-05-02 10:00:00
# 10        company  2020-05-02 10:00:00
# 11        company  2020-05-02 09:44:45
# 12        company  2020-05-02 09:36:00
# 13        company  2020-05-02 09:36:00
# 14   company news  2020-05-02 08:59:52
# 15        company  2020-05-02 08:59:43
# 16        company  2020-05-02 08:53:22
# 17   company news  2020-05-02 08:51:00
# 18        company  2020-05-02 08:50:19
# 19        company  2020-05-02 08:25:34
# 20        company  2020-05-02 08:01:20
# 21   company news  2020-05-02 07:49:00
# 22        company  2020-05-02 07:47:02
# ...

# %%
news_df
# Out:
#          category    datetime  \
# 0         company  1588377600
# 1         company  1588377600
# 2         company  1588377600
# 3         company  1588377600
# 4         company  1588377600
# 5         company  1588377600
# 6         company  1588377600
# 7         company  1588377600
# 8         company  1588377600
# 9         company  1588377600
# 10        company  1588377600
# 11        company  1588376685
# 12        company  1588376160
# 13        company  1588376160
# 14   company news  1588373992
# 15        company  1588373983
# 16        company  1588373602
# 17   company news  1588373460
# 18        company  1588373419
# 19        company  1588371934
# 20        company  1588370480
# 21   company news  1588369740
# 22        company  1588369622
# 23        company  1588368102
# 24        company  1588367762
# 25        company  1588367700
# 26        company  1588367641
# 27   company news  1588367562
# 28   company news  1588367562
# 29        company  1588366973
# ...

# %%
# c0tpqan48v6qoe9bm5o0
